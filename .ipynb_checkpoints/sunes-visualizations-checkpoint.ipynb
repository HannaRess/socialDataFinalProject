# %% [markdown]
# # Final project vizulations (Sunes work)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
import folium
import urllib.request
import datetime
import plotly.express as px
from folium import plugins
from folium.plugins import HeatMap

# %%
df = pd.read_csv("data/weather.csv") 
df
# Out:
#             date  tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  \
# 0     2019-01-01  19.7  15.4  24.7   0.0   NaN  189.0  14.0   NaN  1012.3
# 1     2019-01-02  19.2  16.1  22.7   0.0   NaN  171.0  17.5   NaN  1013.1
# 2     2019-01-03  21.2  15.0  28.6   0.0   NaN  174.0  12.8   NaN  1011.1
# 3     2019-01-04  26.5  19.1  37.4   0.0   NaN  323.0  22.8   NaN  1006.4
# 4     2019-01-05  17.1  14.5  18.6   0.3   NaN  185.0  19.4   NaN  1013.3
# ...          ...   ...   ...   ...   ...   ...    ...   ...   ...     ...
# 1185  2022-03-31  15.2  12.6  18.3   0.0   NaN  153.0  19.1   NaN  1023.4
# 1186  2022-04-01  14.7  11.7  18.3   0.0   NaN  141.0  19.8   NaN  1026.8
# 1187  2022-04-02  15.2  12.4  17.6   0.0   NaN  148.0  16.8   NaN  1022.1
# 1188  2022-04-03  15.7  13.9  17.4   1.1   NaN  164.0  11.7   NaN  1015.7
# 1189  2022-04-04  15.9  13.1  19.4   0.0   NaN  247.0  11.9   NaN  1014.5
#
#       tsun
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 1185   NaN
# 1186   NaN
# 1187   NaN
# 1188   NaN
# 1189   NaN
#
# [1190 rows x 11 columns]

# %%
x = df["prcp"]
x.max()
plt.hist(x, bins=4)
plt.show()

# %% [markdown]
# ### Weekly patterns. Basically, we'll forget about the yearly variation and just count up what happens during each weekday. Here's what my version looks like. Make your own version of the plot and comment your results.

# %%
df = pd.read_csv("data/Pedestrian_Counting_System_-_Monthly__counts_per_hour_.csv") 
df
# Out:
#               ID                      Date_Time  Year     Month  Mdate  \
# 0        2887628  November 01, 2019 05:00:00 PM  2019  November      1
# 1        2887629  November 01, 2019 05:00:00 PM  2019  November      1
# 2        2887630  November 01, 2019 05:00:00 PM  2019  November      1
# 3        2887631  November 01, 2019 05:00:00 PM  2019  November      1
# 4        2887632  November 01, 2019 05:00:00 PM  2019  November      1
# ...          ...                            ...   ...       ...    ...
# 4176213  4181685  February 24, 2022 08:00:00 PM  2022  February     24
# 4176214  4181686  February 24, 2022 09:00:00 PM  2022  February     24
# 4176215  4181687  February 24, 2022 10:00:00 PM  2022  February     24
# 4176216  4181688  February 24, 2022 11:00:00 PM  2022  February     24
# 4176217  4181689  February 25, 2022 12:00:00 AM  2022  February     25
#
#               Day  Time  Sensor_ID                        Sensor_Name  \
# 0          Friday    17         34               Flinders St-Spark La
# 1          Friday    17         39                       Alfred Place
# 2          Friday    17         37                    Lygon St (East)
# 3          Friday    17         40       Lonsdale St-Spring St (West)
# 4          Friday    17         36                    Queen St (West)
# ...           ...   ...        ...                                ...
# 4176213  Thursday    20         86  Queensberry St - Errol St (South)
# 4176214  Thursday    21         86  Queensberry St - Errol St (South)
# 4176215  Thursday    22         86  Queensberry St - Errol St (South)
# 4176216  Thursday    23         86  Queensberry St - Errol St (South)
# 4176217    Friday     0         86  Queensberry St - Errol St (South)
#
#          Hourly_Counts
# 0                  300
# 1                  604
# 2                  216
# 3                  627
# 4                  774
# ...                ...
# 4176213             69
# 4176214             46
# 4176215             52
# 4176216              9
# 4176217              4
#
# [4176218 rows x 10 columns]

# %%
x = df[df.Hourly_Counts < 3000]

# %%
plt.hist(x.Hourly_Counts, bins=8)
plt.show()
